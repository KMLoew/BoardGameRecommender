# %% [markdown]
# Last Modified: September 5, 2019
#
# Description: This program scraps the data from boardgamegeek.com. It grabs usernames, game names, gameids, and ratings.

# %% [markdown]
# This code was taken from the following link and slightly modified for my purposes.
#
# https://sdsawtelle.github.io/blog/output/boardgamegeek-data-scraping.html
#
# The code is explained in detail above and the project is well worth the time to read.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from bs4 import BeautifulSoup
import requests
import scipy.io
import pandas as pd
import numpy as np
import pickle
from time import sleep
import timeit
from math import ceil

# %% [markdown]
# I wanted a progress bar to tell me how close to finished I was. This was taken from https://stackoverflow.com/questions/3160699/python-progress-bar

# %%
def show_progress_bar(bar_length, completed, total):

    '''
    Produces progress bar to let user know how far along the simulation is.

    This function was pulled from https://stackoverflow.com/questions/3160699/python-progress-bar.

    PARAMETERS:
    bar_length: (int) Number of '#' in bar
    competed: (int) Number of iterations finished 
    total: (int) Total number of iterations to finish the simulation
    '''
    
    bar_length_unit_value = (total / bar_length)
    completed_bar_part = ceil(completed / bar_length_unit_value) 
    progress = '*'*completed_bar_part
    remaining = ' '*(bar_length - completed_bar_part)
    percent_done = '%.2f' % ((completed / total) * 100)
    print(f'[{progress}{remaining}] {percent_done}%', end='\r')

# %% [markdown]
# This function handles the requests from the server. If the server gives an error, it retries.
#
# A key addition is the timeout. Typically the request.get() call will try forever to get the information. The timeout specifies that it should cancel the request at a certain point. This triggers the retry and attempts to get the data again.

# %%
def request(msg, slp=1):
    status_code=0  
    while status_code!=200:
        sleep(slp)
        try:
            out=requests.get(msg,timeout=60)
            status_code=out.status_code
            if status_code!=200:
                print('Server Error! Response Code %i. Retrying...' % (out.status_code))
        except:
            print('Retrying...\nWaiting one seconds...')
            sleep(1)
    return out

# %% [markdown]
# A dataframe is generated to store the gameid, name, and the total number of ratings of that game.
#
# It gets games with at least 100 ratings.

# %%
df_all=pd.DataFrame(columns=['id', 'name', 'nrate'])
min_nrate=10**6
npage=1

while min_nrate>99:
    r=request('https://boardgamegeek.com/browse/boardgame/page/%i?sort=numvoters&sortdir=desc' % (npage,))
    soup=BeautifulSoup(r.text, 'html.parser')    
    
    
    table=soup.find_all('tr', attrs={'id': 'row_'}) 
    df=pd.DataFrame(columns=['id', 'name', 'nrate'], index=range(len(table)))  
    
    for idx, row in enumerate(table):
        links=row.find_all('a')
        if 'name' in links[0].attrs.keys():
            del links[0]
        gamelink=links[1]  # Get the relative URL for the specific game
        gameid=int(gamelink['href'].split('/')[2])  # Get the game ID by parsing the relative URL
        gamename=gamelink.contents[0]  # Get the actual name of the game as the link contents


        ratings_str=row.find_all('td', attrs={'class': 'collection_bggrating'})[2].contents[0]
        nratings=int(''.join(ratings_str.split()))

        df.iloc[idx, :]=[gameid, gamename, nratings]

    min_nrate=df['nrate'].min()  # The smallest number of ratings of any game on the page
    print('Page %i scraped, minimum number of ratings was %i' % (npage, min_nrate))
    df_all=pd.concat([df_all, df], axis=0)
    npage+=1
    sleep(1)
# Out:
# Page 1 scraped, minimum number of ratings was 19053
# Page 2 scraped, minimum number of ratings was 12296
# Page 3 scraped, minimum number of ratings was 9043
# Page 4 scraped, minimum number of ratings was 7128
# Page 5 scraped, minimum number of ratings was 5918
# Page 6 scraped, minimum number of ratings was 4860
# Page 7 scraped, minimum number of ratings was 4179
# Page 8 scraped, minimum number of ratings was 3699
# Page 9 scraped, minimum number of ratings was 3264
# Page 10 scraped, minimum number of ratings was 2912
# Page 11 scraped, minimum number of ratings was 2666
# Page 12 scraped, minimum number of ratings was 2428
# Page 13 scraped, minimum number of ratings was 2211
# Page 14 scraped, minimum number of ratings was 2036
# Page 15 scraped, minimum number of ratings was 1879
# Page 16 scraped, minimum number of ratings was 1750
# Page 17 scraped, minimum number of ratings was 1644
# Page 18 scraped, minimum number of ratings was 1560
# Page 19 scraped, minimum number of ratings was 1466
# Page 20 scraped, minimum number of ratings was 1388
# Page 21 scraped, minimum number of ratings was 1319
# Page 22 scraped, minimum number of ratings was 1245
# Page 23 scraped, minimum number of ratings was 1177
# Page 24 scraped, minimum number of ratings was 1113
# Page 25 scraped, minimum number of ratings was 1050
# Page 26 scraped, minimum number of ratings was 1002
# Page 27 scraped, minimum number of ratings was 964
# Page 28 scraped, minimum number of ratings was 920
# Page 29 scraped, minimum number of ratings was 885
# Page 30 scraped, minimum number of ratings was 843
# Page 31 scraped, minimum number of ratings was 812
# Page 32 scraped, minimum number of ratings was 776
# Page 33 scraped, minimum number of ratings was 749
# Page 34 scraped, minimum number of ratings was 718
# Page 35 scraped, minimum number of ratings was 693
# Page 36 scraped, minimum number of ratings was 670
# Page 37 scraped, minimum number of ratings was 642
# Page 38 scraped, minimum number of ratings was 617
# Page 39 scraped, minimum number of ratings was 596
# Page 40 scraped, minimum number of ratings was 575
# Page 41 scraped, minimum number of ratings was 552
# Page 42 scraped, minimum number of ratings was 535
# Page 43 scraped, minimum number of ratings was 518
# Page 44 scraped, minimum number of ratings was 503
# Page 45 scraped, minimum number of ratings was 488
# Page 46 scraped, minimum number of ratings was 473
# Page 47 scraped, minimum number of ratings was 457
# Page 48 scraped, minimum number of ratings was 443
# Page 49 scraped, minimum number of ratings was 429
# Page 50 scraped, minimum number of ratings was 416
# Page 51 scraped, minimum number of ratings was 405
# Page 52 scraped, minimum number of ratings was 393
# Page 53 scraped, minimum number of ratings was 383
# Page 54 scraped, minimum number of ratings was 375
# Page 55 scraped, minimum number of ratings was 366
# Page 56 scraped, minimum number of ratings was 355
# Page 57 scraped, minimum number of ratings was 345
# Page 58 scraped, minimum number of ratings was 337
# Page 59 scraped, minimum number of ratings was 327
# Page 60 scraped, minimum number of ratings was 317
# Page 61 scraped, minimum number of ratings was 310
# Page 62 scraped, minimum number of ratings was 302
# Page 63 scraped, minimum number of ratings was 295
# Page 64 scraped, minimum number of ratings was 289
# Page 65 scraped, minimum number of ratings was 281
# Page 66 scraped, minimum number of ratings was 275
# Page 67 scraped, minimum number of ratings was 269
# Page 68 scraped, minimum number of ratings was 265
# Page 69 scraped, minimum number of ratings was 259
# Page 70 scraped, minimum number of ratings was 254
# Page 71 scraped, minimum number of ratings was 249
# Page 72 scraped, minimum number of ratings was 244
# Page 73 scraped, minimum number of ratings was 239
# Page 74 scraped, minimum number of ratings was 235
# Page 75 scraped, minimum number of ratings was 230
# Page 76 scraped, minimum number of ratings was 226
# Page 77 scraped, minimum number of ratings was 221
# Page 78 scraped, minimum number of ratings was 217
# Page 79 scraped, minimum number of ratings was 213
# Page 80 scraped, minimum number of ratings was 209
# Page 81 scraped, minimum number of ratings was 205
# Page 82 scraped, minimum number of ratings was 201
# Page 83 scraped, minimum number of ratings was 197
# Page 84 scraped, minimum number of ratings was 193
# Page 85 scraped, minimum number of ratings was 189
# Page 86 scraped, minimum number of ratings was 186
# Page 87 scraped, minimum number of ratings was 183
# Page 88 scraped, minimum number of ratings was 180
# Page 89 scraped, minimum number of ratings was 176
# Page 90 scraped, minimum number of ratings was 173
# Page 91 scraped, minimum number of ratings was 170
# Page 92 scraped, minimum number of ratings was 167
# Page 93 scraped, minimum number of ratings was 164
# Page 94 scraped, minimum number of ratings was 161
# Page 95 scraped, minimum number of ratings was 159
# Page 96 scraped, minimum number of ratings was 156
# Page 97 scraped, minimum number of ratings was 153
# Page 98 scraped, minimum number of ratings was 150
# Page 99 scraped, minimum number of ratings was 148
# Page 100 scraped, minimum number of ratings was 146
# Page 101 scraped, minimum number of ratings was 143
# Page 102 scraped, minimum number of ratings was 141
# Page 103 scraped, minimum number of ratings was 139
# Page 104 scraped, minimum number of ratings was 136
# Page 105 scraped, minimum number of ratings was 134
# Page 106 scraped, minimum number of ratings was 132
# Page 107 scraped, minimum number of ratings was 130
# Page 108 scraped, minimum number of ratings was 128
# Page 109 scraped, minimum number of ratings was 126
# Page 110 scraped, minimum number of ratings was 124
# Page 111 scraped, minimum number of ratings was 122
# Page 112 scraped, minimum number of ratings was 121
# Page 113 scraped, minimum number of ratings was 119
# Page 114 scraped, minimum number of ratings was 117
# Page 115 scraped, minimum number of ratings was 115
# Page 116 scraped, minimum number of ratings was 114
# Page 117 scraped, minimum number of ratings was 112
# Page 118 scraped, minimum number of ratings was 111
# Page 119 scraped, minimum number of ratings was 109
# Page 120 scraped, minimum number of ratings was 107
# Page 121 scraped, minimum number of ratings was 106
# Page 122 scraped, minimum number of ratings was 105
# Page 123 scraped, minimum number of ratings was 103
# Page 124 scraped, minimum number of ratings was 102
# Page 125 scraped, minimum number of ratings was 100
# Page 126 scraped, minimum number of ratings was 99

# %% [markdown]
# The dataframe is then saved to a csv file.

# %%
df=df_all.copy()
df.reset_index(inplace=True, drop=True)
df.to_csv('bgg_gamelist.csv', index=False)
df.head()
# Out:
#       id         name  nrate
# 0     13        Catan  87271
# 1    822  Carcassonne  86952
# 2  30549     Pandemic  85739
# 3  68448    7 Wonders  70996
# 4  36218     Dominion  69531

# %% [markdown]
# There are 100 ratings per page, so another column of the number of full pages of ratings is stored.

# %%
df['nfullpages'] = (df['nrate']-50).apply(round, ndigits=-2)//100  # Round DOWN to nearest 100
df.head()
# Out:
#       id         name  nrate  nfullpages
# 0     13        Catan  87271         872
# 1    822  Carcassonne  86952         869
# 2  30549     Pandemic  85739         857
# 3  68448    7 Wonders  70996         709
# 4  36218     Dominion  69531         695

# %% [markdown]
# A new dataframe df_ratings is declared to store usernames, gameids, and ratings. The code loops over a group of 20 games and stores the ratings for all of the full pages.
#
# These ratings are periodically saved to a csv.

# %%
bar_counter=0
bar_total=len(df)//20

for nm, grp in df.groupby(np.arange(len(df))//20):
    df_ratings=pd.DataFrame(columns=['username', 'gameid', 'rating'], index=range(grp['nrate'].sum()+10**3))

    dfidx_start=0
    dfidx=0
    
    pagenum=1
    while len(grp[grp['nfullpages'] > 0]) > 0: 
        active_games=grp[grp['nfullpages'] > 0]

        id_list=[]
        for game in active_games['id']:
            id_list+=[game]*100
        dfidx_end=dfidx_start+len(active_games)*100
        df_ratings.iloc[dfidx_start:dfidx_end, df_ratings.columns.get_loc('gameid')] = id_list

        id_strs=[str(gid) for gid in active_games['id']]
        gameids=','.join(id_strs)
        sleep(0.5)  
        r=request('http://www.boardgamegeek.com/xmlapi2/thing?id=%s&ratingcomments=1&page=%i' % (gameids, pagenum))

        
        soup=BeautifulSoup(r.text, 'xml')
        comments=soup('comment')
        l1=[0]*len(active_games)*100
        l2=[0]*len(active_games)*100
        j=0
        for comm in comments:
            l1[j]=comm['username']
            l2[j]=float(comm['rating'])
            j+=1
        df_ratings.iloc[dfidx_start:dfidx_end, df_ratings.columns.get_loc('username')] = l1
        df_ratings.iloc[dfidx_start:dfidx_end, df_ratings.columns.get_loc('rating')] = l2

        
        grp['nfullpages']-=1  
        dfidx_start=dfidx_end     
        pagenum+=1  
        print('pagenum updated to', pagenum)
    
    print('\nBatch Complete!\n')
    df_ratings=df_ratings.dropna(how='all')
    df_ratings.to_csv('bgg_ratings.csv', mode='a',index=False)
    del df_ratings
    bar_counter+=1
    show_progress_bar(100,bar_counter,bar_total)
# Out:
# /home/kloew/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# pagenum updated to 2
# pagenum updated to 3
# pagenum updated to 4
# pagenum updated to 5
# pagenum updated to 6
# pagenum updated to 7
# pagenum updated to 8
# pagenum updated to 9
# pagenum updated to 10
# pagenum updated to 11
# pagenum updated to 12
# pagenum updated to 13
# pagenum updated to 14
# pagenum updated to 15
# pagenum updated to 16
# pagenum updated to 17
# pagenum updated to 18
# pagenum updated to 19
# pagenum updated to 20
# pagenum updated to 21
# Retrying...
# Waiting one seconds...
# pagenum updated to 22
# pagenum updated to 23
# pagenum updated to 24
# pagenum updated to 25
# pagenum updated to 26
# pagenum updated to 27
# pagenum updated to 28
# pagenum updated to 29
# pagenum updated to 30
# pagenum updated to 31
# pagenum updated to 32
# pagenum updated to 33
# pagenum updated to 34
# pagenum updated to 35
# pagenum updated to 36
# pagenum updated to 37
# pagenum updated to 38
# pagenum updated to 39
# pagenum updated to 40
# pagenum updated to 41
# pagenum updated to 42
# pagenum updated to 43
# pagenum updated to 44
# pagenum updated to 45
# pagenum updated to 46
# pagenum updated to 47
# pagenum updated to 48
# pagenum updated to 49
# pagenum updated to 50
# pagenum updated to 51
# pagenum updated to 52
# pagenum updated to 53
# pagenum updated to 54
# pagenum updated to 55
# pagenum updated to 56
# pagenum updated to 57
# pagenum updated to 58
# pagenum updated to 59
# pagenum updated to 60
# pagenum updated to 61
# pagenum updated to 62
# pagenum updated to 63
# pagenum updated to 64
# pagenum updated to 65
# pagenum updated to 66
# pagenum updated to 67
# pagenum updated to 68
# pagenum updated to 69
# pagenum updated to 70
# pagenum updated to 71
# pagenum updated to 72
# pagenum updated to 73
# pagenum updated to 74
# pagenum updated to 75
# pagenum updated to 76
# pagenum updated to 77
# pagenum updated to 78
# pagenum updated to 79
# pagenum updated to 80
# pagenum updated to 81
# pagenum updated to 82
# pagenum updated to 83
# pagenum updated to 84
# pagenum updated to 85
# pagenum updated to 86
# pagenum updated to 87
# pagenum updated to 88
# pagenum updated to 89
# pagenum updated to 90
# pagenum updated to 91
# pagenum updated to 92
# pagenum updated to 93
# pagenum updated to 94
# pagenum updated to 95
# pagenum updated to 96
# pagenum updated to 97
# pagenum updated to 98
# pagenum updated to 99
# pagenum updated to 100
# pagenum updated to 101
# pagenum updated to 102
# pagenum updated to 103
# pagenum updated to 104
# pagenum updated to 105
# pagenum updated to 106
# pagenum updated to 107
# pagenum updated to 108
# pagenum updated to 109
# pagenum updated to 110
# pagenum updated to 111
# pagenum updated to 112
# pagenum updated to 113
# pagenum updated to 114
# pagenum updated to 115
# pagenum updated to 116
# pagenum updated to 117
# pagenum updated to 118
# pagenum updated to 119
# pagenum updated to 120
# pagenum updated to 121
# pagenum updated to 122
# pagenum updated to 123
# pagenum updated to 124
# pagenum updated to 125
# pagenum updated to 126
# pagenum updated to 127
# pagenum updated to 128
# pagenum updated to 129
# pagenum updated to 130
# pagenum updated to 131
# pagenum updated to 132
# pagenum updated to 133
# pagenum updated to 134
# pagenum updated to 135
# pagenum updated to 136
# pagenum updated to 137
# pagenum updated to 138
# pagenum updated to 139
# pagenum updated to 140
# pagenum updated to 141
# pagenum updated to 142
# pagenum updated to 143
# pagenum updated to 144
# pagenum updated to 145
# pagenum updated to 146
# pagenum updated to 147
# pagenum updated to 148
# pagenum updated to 149
# pagenum updated to 150
# pagenum updated to 151
# pagenum updated to 152
# pagenum updated to 153
# pagenum updated to 154
# pagenum updated to 155
# pagenum updated to 156
# pagenum updated to 157
# pagenum updated to 158
# pagenum updated to 159
# pagenum updated to 160
# pagenum updated to 161
# pagenum updated to 162
# pagenum updated to 163
# pagenum updated to 164
# pagenum updated to 165
# pagenum updated to 166
# pagenum updated to 167
# pagenum updated to 168
# pagenum updated to 169
# pagenum updated to 170
# pagenum updated to 171
# pagenum updated to 172
# pagenum updated to 173
# pagenum updated to 174
# pagenum updated to 175
# pagenum updated to 176
# pagenum updated to 177
# pagenum updated to 178
# pagenum updated to 179
# pagenum updated to 180
# pagenum updated to 181
# pagenum updated to 182
# pagenum updated to 183
# pagenum updated to 184
# pagenum updated to 185
# pagenum updated to 186
# pagenum updated to 187
# pagenum updated to 188
# pagenum updated to 189
# pagenum updated to 190
# pagenum updated to 191
# pagenum updated to 192
# pagenum updated to 193
# pagenum updated to 194
# pagenum updated to 195
# pagenum updated to 196
# pagenum updated to 197
# pagenum updated to 198
# pagenum updated to 199
# pagenum updated to 200
# pagenum updated to 201
# pagenum updated to 202
# pagenum updated to 203
# pagenum updated to 204
# pagenum updated to 205
# pagenum updated to 206
# pagenum updated to 207
# pagenum updated to 208
# pagenum updated to 209
# pagenum updated to 210
# pagenum updated to 211
# pagenum updated to 212
# pagenum updated to 213
# pagenum updated to 214
# pagenum updated to 215
# pagenum updated to 216
# pagenum updated to 217
# pagenum updated to 218
# pagenum updated to 219
# pagenum updated to 220
# pagenum updated to 221
# pagenum updated to 222
# pagenum updated to 223
# pagenum updated to 224
# pagenum updated to 225
# pagenum updated to 226
# pagenum updated to 227
# pagenum updated to 228
# pagenum updated to 229
# pagenum updated to 230
# pagenum updated to 231
# pagenum updated to 232
# pagenum updated to 233
# pagenum updated to 234
# pagenum updated to 235
# pagenum updated to 236
# pagenum updated to 237
# pagenum updated to 238
# pagenum updated to 239
# pagenum updated to 240
# pagenum updated to 241
# pagenum updated to 242
# pagenum updated to 243
# pagenum updated to 244
# pagenum updated to 245
# pagenum updated to 246
# pagenum updated to 247
# pagenum updated to 248
# pagenum updated to 249
# pagenum updated to 250
# pagenum updated to 251
# pagenum updated to 252
# pagenum updated to 253
# pagenum updated to 254
# pagenum updated to 255
# pagenum updated to 256
# pagenum updated to 257
# pagenum updated to 258
# pagenum updated to 259
# pagenum updated to 260
# pagenum updated to 261
# pagenum updated to 262
# pagenum updated to 263
# pagenum updated to 264
# pagenum updated to 265
# pagenum updated to 266
# pagenum updated to 267
# pagenum updated to 268
# pagenum updated to 269
# pagenum updated to 270
# pagenum updated to 271
# pagenum updated to 272
# pagenum updated to 273
# pagenum updated to 274
# pagenum updated to 275
# pagenum updated to 276
# pagenum updated to 277
# pagenum updated to 278
# pagenum updated to 279
# pagenum updated to 280
# pagenum updated to 281
# pagenum updated to 282
# pagenum updated to 283
# pagenum updated to 284
# pagenum updated to 285
# pagenum updated to 286
# pagenum updated to 287
# pagenum updated to 288
# pagenum updated to 289
# pagenum updated to 290
# pagenum updated to 291
# pagenum updated to 292
# pagenum updated to 293
# pagenum updated to 294
# pagenum updated to 295
# pagenum updated to 296
# pagenum updated to 297
# pagenum updated to 298
# pagenum updated to 299
# pagenum updated to 300
# pagenum updated to 301
# pagenum updated to 302
# pagenum updated to 303
# pagenum updated to 304
# pagenum updated to 305
# pagenum updated to 306
# pagenum updated to 307
# pagenum updated to 308
# pagenum updated to 309
# pagenum updated to 310
# pagenum updated to 311
# pagenum updated to 312
# pagenum updated to 313
# pagenum updated to 314
# pagenum updated to 315
# pagenum updated to 316
# pagenum updated to 317
# pagenum updated to 318
# pagenum updated to 319
# pagenum updated to 320
# pagenum updated to 321
# pagenum updated to 322
# pagenum updated to 323
# pagenum updated to 324
# pagenum updated to 325
# pagenum updated to 326
# pagenum updated to 327
# pagenum updated to 328
# pagenum updated to 329
# pagenum updated to 330
# pagenum updated to 331
# pagenum updated to 332
# pagenum updated to 333
# pagenum updated to 334
# pagenum updated to 335
# pagenum updated to 336
# pagenum updated to 337
# pagenum updated to 338
# pagenum updated to 339
# pagenum updated to 340
# pagenum updated to 341
# pagenum updated to 342
# pagenum updated to 343
# pagenum updated to 344
# pagenum updated to 345
# pagenum updated to 346
# pagenum updated to 347
# pagenum updated to 348
# pagenum updated to 349
# pagenum updated to 350
# pagenum updated to 351
# pagenum updated to 352
# pagenum updated to 353
# pagenum updated to 354
# pagenum updated to 355
# pagenum updated to 356
# pagenum updated to 357
# pagenum updated to 358
# pagenum updated to 359
# pagenum updated to 360
# pagenum updated to 361
# pagenum updated to 362
# pagenum updated to 363
# pagenum updated to 364
# pagenum updated to 365
# pagenum updated to 366
# pagenum updated to 367
# pagenum updated to 368
# pagenum updated to 369
# pagenum updated to 370
# pagenum updated to 371
# pagenum updated to 372
# pagenum updated to 373
# pagenum updated to 374
# pagenum updated to 375
# pagenum updated to 376
# pagenum updated to 377
# pagenum updated to 378
# pagenum updated to 379
# pagenum updated to 380
# pagenum updated to 381
# pagenum updated to 382
# pagenum updated to 383
# pagenum updated to 384
# pagenum updated to 385
# pagenum updated to 386
# pagenum updated to 387
# pagenum updated to 388
# pagenum updated to 389
# pagenum updated to 390
# pagenum updated to 391
# pagenum updated to 392
# pagenum updated to 393
# pagenum updated to 394
# pagenum updated to 395
# pagenum updated to 396
# pagenum updated to 397
# pagenum updated to 398
# pagenum updated to 399
# pagenum updated to 400
# pagenum updated to 401
# pagenum updated to 402
# pagenum updated to 403
# pagenum updated to 404
# pagenum updated to 405
# pagenum updated to 406
# pagenum updated to 407
# pagenum updated to 408
# pagenum updated to 409
# pagenum updated to 410
# pagenum updated to 411
# pagenum updated to 412
# pagenum updated to 413
# pagenum updated to 414
# pagenum updated to 415
# pagenum updated to 416
# pagenum updated to 417
# pagenum updated to 418
# pagenum updated to 419
# pagenum updated to 420
# pagenum updated to 421
# pagenum updated to 422
# pagenum updated to 423
# pagenum updated to 424
# pagenum updated to 425
# pagenum updated to 426
# pagenum updated to 427
# pagenum updated to 428
# pagenum updated to 429
# pagenum updated to 430
# pagenum updated to 431
# pagenum updated to 432
# pagenum updated to 433
# pagenum updated to 434
# pagenum updated to 435
# pagenum updated to 436
# pagenum updated to 437
# pagenum updated to 438
# pagenum updated to 439
# pagenum updated to 440
# pagenum updated to 441
# pagenum updated to 442
# pagenum updated to 443
# pagenum updated to 444
# pagenum updated to 445
# pagenum updated to 446
# pagenum updated to 447
# pagenum updated to 448
# pagenum updated to 449
# pagenum updated to 450
# pagenum updated to 451
# pagenum updated to 452
# pagenum updated to 453
# pagenum updated to 454
# pagenum updated to 455
# pagenum updated to 456
# pagenum updated to 457
# pagenum updated to 458
# pagenum updated to 459
# pagenum updated to 460
# pagenum updated to 461
# pagenum updated to 462
# pagenum updated to 463
# pagenum updated to 464
# pagenum updated to 465
# pagenum updated to 466
# pagenum updated to 467
# pagenum updated to 468
# pagenum updated to 469
# pagenum updated to 470
# pagenum updated to 471
# pagenum updated to 472
# pagenum updated to 473
# pagenum updated to 474
# pagenum updated to 475
# pagenum updated to 476
# pagenum updated to 477
# pagenum updated to 478
# pagenum updated to 479
# pagenum updated to 480
# pagenum updated to 481
# pagenum updated to 482
# pagenum updated to 483
# pagenum updated to 484
# pagenum updated to 485
# pagenum updated to 486
# pagenum updated to 487
# pagenum updated to 488
# pagenum updated to 489
# pagenum updated to 490
# pagenum updated to 491
# pagenum updated to 492
# pagenum updated to 493
# pagenum updated to 494
# pagenum updated to 495
# pagenum updated to 496
# pagenum updated to 497
# pagenum updated to 498
# pagenum updated to 499
# pagenum updated to 500
# pagenum updated to 501
# pagenum updated to 502
# pagenum updated to 503
# pagenum updated to 504
# pagenum updated to 505
# pagenum updated to 506
# pagenum updated to 507
# pagenum updated to 508
# pagenum updated to 509
# pagenum updated to 510
# pagenum updated to 511
# pagenum updated to 512
# pagenum updated to 513
# pagenum updated to 514
# pagenum updated to 515
# pagenum updated to 516
# pagenum updated to 517
# pagenum updated to 518
# pagenum updated to 519
# pagenum updated to 520
# pagenum updated to 521
# pagenum updated to 522
# pagenum updated to 523
# pagenum updated to 524
# pagenum updated to 525
# pagenum updated to 526
# pagenum updated to 527
# pagenum updated to 528
# pagenum updated to 529
# pagenum updated to 530
# pagenum updated to 531
# pagenum updated to 532
# pagenum updated to 533
# pagenum updated to 534
# pagenum updated to 535
# pagenum updated to 536
# pagenum updated to 537
# pagenum updated to 538
# pagenum updated to 539
# pagenum updated to 540
# pagenum updated to 541
# pagenum updated to 542
# pagenum updated to 543
# pagenum updated to 544
# pagenum updated to 545
# pagenum updated to 546
# pagenum updated to 547
# pagenum updated to 548
# pagenum updated to 549
# pagenum updated to 550
# pagenum updated to 551
# pagenum updated to 552
# pagenum updated to 553
# pagenum updated to 554
# pagenum updated to 555
# pagenum updated to 556
# pagenum updated to 557
# pagenum updated to 558
# pagenum updated to 559
# pagenum updated to 560
# pagenum updated to 561
# pagenum updated to 562
# pagenum updated to 563
# pagenum updated to 564
# pagenum updated to 565
# pagenum updated to 566
# pagenum updated to 567
# pagenum updated to 568
# pagenum updated to 569
# pagenum updated to 570
# pagenum updated to 571
# pagenum updated to 572
# pagenum updated to 573
# pagenum updated to 574
# pagenum updated to 575
# pagenum updated to 576
# pagenum updated to 577
# pagenum updated to 578
# pagenum updated to 579
# pagenum updated to 580
# pagenum updated to 581
# pagenum updated to 582
# pagenum updated to 583
# pagenum updated to 584
# pagenum updated to 585
# pagenum updated to 586
# pagenum updated to 587
# pagenum updated to 588
# pagenum updated to 589
# pagenum updated to 590
# pagenum updated to 591
# pagenum updated to 592
# pagenum updated to 593
# pagenum updated to 594
# pagenum updated to 595
# pagenum updated to 596
# pagenum updated to 597
# pagenum updated to 598
# pagenum updated to 599
# pagenum updated to 600
# pagenum updated to 601
# pagenum updated to 602
# pagenum updated to 603
# pagenum updated to 604
# pagenum updated to 605
# pagenum updated to 606
# pagenum updated to 607
# pagenum updated to 608
# pagenum updated to 609
# pagenum updated to 610
# pagenum updated to 611
# pagenum updated to 612
# pagenum updated to 613
# pagenum updated to 614
# pagenum updated to 615
# pagenum updated to 616
# pagenum updated to 617
# pagenum updated to 618
# pagenum updated to 619
# pagenum updated to 620
# pagenum updated to 621
# pagenum updated to 622
# pagenum updated to 623
# pagenum updated to 624
# pagenum updated to 625
# pagenum updated to 626
# pagenum updated to 627
# pagenum updated to 628
# pagenum updated to 629
# pagenum updated to 630
# pagenum updated to 631
# pagenum updated to 632
# pagenum updated to 633
# pagenum updated to 634
# pagenum updated to 635
# pagenum updated to 636
# pagenum updated to 637
# pagenum updated to 638
# pagenum updated to 639
# pagenum updated to 640
# pagenum updated to 641
# pagenum updated to 642
# pagenum updated to 643
# pagenum updated to 644
# pagenum updated to 645
# pagenum updated to 646
# pagenum updated to 647
# pagenum updated to 648
# pagenum updated to 649
# pagenum updated to 650
# pagenum updated to 651
# pagenum updated to 652
# pagenum updated to 653
# pagenum updated to 654
# pagenum updated to 655
# pagenum updated to 656
# pagenum updated to 657
# pagenum updated to 658
# pagenum updated to 659
# pagenum updated to 660
# pagenum updated to 661
# pagenum updated to 662
# pagenum updated to 663
# pagenum updated to 664
# pagenum updated to 665
# pagenum updated to 666
# pagenum updated to 667
# pagenum updated to 668
# pagenum updated to 669
# pagenum updated to 670
# pagenum updated to 671
# pagenum updated to 672
# pagenum updated to 673
# pagenum updated to 674
# pagenum updated to 675
# pagenum updated to 676
# pagenum updated to 677
# pagenum updated to 678
# pagenum updated to 679
# pagenum updated to 680
# pagenum updated to 681
# pagenum updated to 682
# pagenum updated to 683
# pagenum updated to 684
# pagenum updated to 685
# pagenum updated to 686
# pagenum updated to 687
# pagenum updated to 688
# pagenum updated to 689
# pagenum updated to 690
# pagenum updated to 691
# pagenum updated to 692
# pagenum updated to 693
# pagenum updated to 694
# pagenum updated to 695
# pagenum updated to 696
# pagenum updated to 697
# pagenum updated to 698
# pagenum updated to 699
# pagenum updated to 700
# pagenum updated to 701
# pagenum updated to 702
# pagenum updated to 703
# pagenum updated to 704
# pagenum updated to 705
# pagenum updated to 706
# pagenum updated to 707
# pagenum updated to 708
# pagenum updated to 709
# pagenum updated to 710
# pagenum updated to 711
# pagenum updated to 712
# pagenum updated to 713
# pagenum updated to 714
# pagenum updated to 715
# pagenum updated to 716
# pagenum updated to 717
# pagenum updated to 718
# pagenum updated to 719
# pagenum updated to 720
# pagenum updated to 721
# pagenum updated to 722
# pagenum updated to 723
# pagenum updated to 724
# pagenum updated to 725
# pagenum updated to 726
# pagenum updated to 727
# pagenum updated to 728
# pagenum updated to 729
# pagenum updated to 730
# pagenum updated to 731
# pagenum updated to 732
# pagenum updated to 733
# pagenum updated to 734
# pagenum updated to 735
# pagenum updated to 736
# pagenum updated to 737
# pagenum updated to 738
# pagenum updated to 739
# pagenum updated to 740
# pagenum updated to 741
# pagenum updated to 742
# pagenum updated to 743
# pagenum updated to 744
# pagenum updated to 745
# pagenum updated to 746
# pagenum updated to 747
# pagenum updated to 748
# pagenum updated to 749
# pagenum updated to 750
# pagenum updated to 751
# pagenum updated to 752
# pagenum updated to 753
# pagenum updated to 754
# pagenum updated to 755
# pagenum updated to 756
# pagenum updated to 757
# pagenum updated to 758
# pagenum updated to 759
# pagenum updated to 760
# pagenum updated to 761
# pagenum updated to 762
# pagenum updated to 763
# pagenum updated to 764
# pagenum updated to 765
# pagenum updated to 766
# pagenum updated to 767
# pagenum updated to 768
# pagenum updated to 769
# pagenum updated to 770
# pagenum updated to 771
# pagenum updated to 772
# pagenum updated to 773
# pagenum updated to 774
# pagenum updated to 775
# pagenum updated to 776
# pagenum updated to 777
# pagenum updated to 778
# pagenum updated to 779
# pagenum updated to 780
# pagenum updated to 781
# pagenum updated to 782
# pagenum updated to 783
# pagenum updated to 784
# pagenum updated to 785
# pagenum updated to 786
# pagenum updated to 787
# pagenum updated to 788
# pagenum updated to 789
# pagenum updated to 790
# pagenum updated to 791
# pagenum updated to 792
# pagenum updated to 793
# pagenum updated to 794
# pagenum updated to 795
# pagenum updated to 796
# pagenum updated to 797
# pagenum updated to 798
# pagenum updated to 799
# pagenum updated to 800
# pagenum updated to 801
# pagenum updated to 802
# pagenum updated to 803
# pagenum updated to 804
# pagenum updated to 805
# pagenum updated to 806
# pagenum updated to 807
# pagenum updated to 808
# pagenum updated to 809
# pagenum updated to 810
# pagenum updated to 811
# pagenum updated to 812
# pagenum updated to 813
# pagenum updated to 814
# pagenum updated to 815
# pagenum updated to 816
# pagenum updated to 817
# pagenum updated to 818
# pagenum updated to 819
# pagenum updated to 820
# pagenum updated to 821
# pagenum updated to 822
# pagenum updated to 823
# pagenum updated to 824
# pagenum updated to 825
# pagenum updated to 826
# pagenum updated to 827
# pagenum updated to 828
# pagenum updated to 829
# pagenum updated to 830
# pagenum updated to 831
# pagenum updated to 832
# pagenum updated to 833
# pagenum updated to 834
# pagenum updated to 835
# pagenum updated to 836
# pagenum updated to 837
# pagenum updated to 838
# pagenum updated to 839
# pagenum updated to 840
# pagenum updated to 841
# pagenum updated to 842
# pagenum updated to 843
# pagenum updated to 844
# pagenum updated to 845
# pagenum updated to 846
# pagenum updated to 847
# pagenum updated to 848
# pagenum updated to 849
# pagenum updated to 850
# pagenum updated to 851
# pagenum updated to 852
# pagenum updated to 853
# pagenum updated to 854
# pagenum updated to 855
# pagenum updated to 856
# pagenum updated to 857
# pagenum updated to 858
# pagenum updated to 859
# pagenum updated to 860
# pagenum updated to 861
# pagenum updated to 862
# pagenum updated to 863
# pagenum updated to 864
# pagenum updated to 865
# pagenum updated to 866
# pagenum updated to 867
# pagenum updated to 868
# pagenum updated to 869
# pagenum updated to 870
# pagenum updated to 871
# pagenum updated to 872
# pagenum updated to 873
# Batch Complete!
# pagenum updated to 2                                                                                 ] 0.16%
# pagenum updated to 3
# pagenum updated to 4
# pagenum updated to 5
# pagenum updated to 6
# pagenum updated to 7
# pagenum updated to 8
# pagenum updated to 9
# pagenum updated to 10
# pagenum updated to 11
# pagenum updated to 12
# pagenum updated to 13
# pagenum updated to 14
# pagenum updated to 15
# pagenum updated to 16
# pagenum updated to 17
# pagenum updated to 18
# pagenum updated to 19
# pagenum updated to 20
# pagenum updated to 21
# pagenum updated to 22
# pagenum updated to 23
# pagenum updated to 24
# pagenum updated to 25
# pagenum updated to 26
# pagenum updated to 27
# pagenum updated to 28
# pagenum updated to 29
# pagenum updated to 30
# pagenum updated to 31
# pagenum updated to 32
# pagenum updated to 33
# pagenum updated to 34
# pagenum updated to 35
# pagenum updated to 36
# pagenum updated to 37
# pagenum updated to 38
# pagenum updated to 39
# pagenum updated to 40
# pagenum updated to 41
# pagenum updated to 42
# pagenum updated to 43
# pagenum updated to 44
# pagenum updated to 45
# pagenum updated to 46
# pagenum updated to 47
# pagenum updated to 48
# pagenum updated to 49
# pagenum updated to 50
# pagenum updated to 51
# pagenum updated to 52
# pagenum updated to 53
# pagenum updated to 54
# pagenum updated to 55
# pagenum updated to 56
# pagenum updated to 57
# pagenum updated to 58
# pagenum updated to 59
# pagenum updated to 60
# pagenum updated to 61
# pagenum updated to 62
# pagenum updated to 63
# pagenum updated to 64
# pagenum updated to 65
# pagenum updated to 66
# pagenum updated to 67
# pagenum updated to 68
# pagenum updated to 69
# pagenum updated to 70
# pagenum updated to 71
# pagenum updated to 72
# pagenum updated to 73
# pagenum updated to 74
# pagenum updated to 75
# pagenum updated to 76
# pagenum updated to 77
# pagenum updated to 78
# pagenum updated to 79
# pagenum updated to 80
# pagenum updated to 81
# pagenum updated to 82
# pagenum updated to 83
# pagenum updated to 84
# pagenum updated to 85
# pagenum updated to 86
# pagenum updated to 87
# pagenum updated to 88
# pagenum updated to 89
# pagenum updated to 90
# pagenum updated to 91
# pagenum updated to 92
# pagenum updated to 93
# pagenum updated to 94
# pagenum updated to 95
# pagenum updated to 96
# pagenum updated to 97
# pagenum updated to 98
# pagenum updated to 99
# pagenum updated to 100
# pagenum updated to 101
# pagenum updated to 102
# pagenum updated to 103
# pagenum updated to 104
# pagenum updated to 105
# pagenum updated to 106
# pagenum updated to 107
# pagenum updated to 108
# pagenum updated to 109
# pagenum updated to 110
# pagenum updated to 111
# pagenum updated to 112
# pagenum updated to 113
# pagenum updated to 114
# pagenum updated to 115
# pagenum updated to 116
# pagenum updated to 117
# pagenum updated to 118
# pagenum updated to 119
# pagenum updated to 120
# pagenum updated to 121
# pagenum updated to 122
# pagenum updated to 123
# pagenum updated to 124
# pagenum updated to 125
# pagenum updated to 126
# pagenum updated to 127
# pagenum updated to 128
# pagenum updated to 129
# pagenum updated to 130
# pagenum updated to 131
# pagenum updated to 132
# pagenum updated to 133
# pagenum updated to 134
# pagenum updated to 135
# pagenum updated to 136
# pagenum updated to 137
# pagenum updated to 138
# pagenum updated to 139
# pagenum updated to 140
# pagenum updated to 141
# pagenum updated to 142
# pagenum updated to 143
# pagenum updated to 144
# pagenum updated to 145
# pagenum updated to 146
# pagenum updated to 147
# pagenum updated to 148
# pagenum updated to 149
# pagenum updated to 150
# pagenum updated to 151
# pagenum updated to 152
# pagenum updated to 153
# pagenum updated to 154
# pagenum updated to 155
# pagenum updated to 156
# pagenum updated to 157
# pagenum updated to 158
# pagenum updated to 159
# pagenum updated to 160
# pagenum updated to 161
# pagenum updated to 162
# pagenum updated to 163
# pagenum updated to 164
# pagenum updated to 165
# pagenum updated to 166
# pagenum updated to 167
# pagenum updated to 168
# pagenum updated to 169
# pagenum updated to 170
# pagenum updated to 171
# pagenum updated to 172
# pagenum updated to 173
# pagenum updated to 174
# pagenum updated to 175
# pagenum updated to 176
# pagenum updated to 177
# pagenum updated to 178
# pagenum updated to 179
# pagenum updated to 180
# pagenum updated to 181
# pagenum updated to 182
# pagenum updated to 183
# pagenum updated to 184
# pagenum updated to 185
# pagenum updated to 186
# pagenum updated to 187
# pagenum updated to 188
# pagenum updated to 189
# pagenum updated to 190
# pagenum updated to 191
# pagenum updated to 192
# pagenum updated to 193
# pagenum updated to 194
# pagenum updated to 195
# pagenum updated to 196
# pagenum updated to 197
# pagenum updated to 198
# pagenum updated to 199
# pagenum updated to 200
# pagenum updated to 201
# pagenum updated to 202
# pagenum updated to 203
# pagenum updated to 204
# pagenum updated to 205
# pagenum updated to 206
# pagenum updated to 207
# pagenum updated to 208
# pagenum updated to 209
# pagenum updated to 210
# pagenum updated to 211
# pagenum updated to 212
# pagenum updated to 213
# pagenum updated to 214
# pagenum updated to 215
# pagenum updated to 216
# pagenum updated to 217
# pagenum updated to 218
# pagenum updated to 219
# pagenum updated to 220
# pagenum updated to 221
# pagenum updated to 222
# pagenum updated to 223
# pagenum updated to 224
# pagenum updated to 225
# pagenum updated to 226
# pagenum updated to 227
# pagenum updated to 228
# pagenum updated to 229
# pagenum updated to 230
# pagenum updated to 231
# pagenum updated to 232
# pagenum updated to 233
# pagenum updated to 234
# pagenum updated to 235
# pagenum updated to 236
# pagenum updated to 237
# pagenum updated to 238
# pagenum updated to 239
# pagenum updated to 240
# pagenum updated to 241
# pagenum updated to 242
# pagenum updated to 243
# pagenum updated to 244
# pagenum updated to 245
# pagenum updated to 246
# pagenum updated to 247
# pagenum updated to 248
# pagenum updated to 249
# pagenum updated to 250
# pagenum updated to 251
# pagenum updated to 252
# pagenum updated to 253
# pagenum updated to 254
# pagenum updated to 255
# pagenum updated to 256
# pagenum updated to 257
# pagenum updated to 258
# pagenum updated to 259
# pagenum updated to 260
# pagenum updated to 261
# pagenum updated to 262
# pagenum updated to 263
# pagenum updated to 264
# pagenum updated to 265
# pagenum updated to 266
# pagenum updated to 267
# pagenum updated to 268
# pagenum updated to 269
# pagenum updated to 270
# pagenum updated to 271
# pagenum updated to 272
# pagenum updated to 273
# pagenum updated to 274
# pagenum updated to 275
# pagenum updated to 276
# pagenum updated to 277
# pagenum updated to 278
# pagenum updated to 279
# pagenum updated to 280
# pagenum updated to 281
# pagenum updated to 282
# pagenum updated to 283
# pagenum updated to 284
# pagenum updated to 285
# pagenum updated to 286
# pagenum updated to 287
# pagenum updated to 288
# pagenum updated to 289
# pagenum updated to 290
# pagenum updated to 291
# pagenum updated to 292
# pagenum updated to 293
# pagenum updated to 294
# pagenum updated to 295
# pagenum updated to 296
# pagenum updated to 297
# pagenum updated to 298
# pagenum updated to 299
# pagenum updated to 300
# pagenum updated to 301
# pagenum updated to 302
# pagenum updated to 303
# pagenum updated to 304
# pagenum updated to 305
# pagenum updated to 306
# pagenum updated to 307
# pagenum updated to 308
# pagenum updated to 309
# pagenum updated to 310
# pagenum updated to 311
# pagenum updated to 312
# pagenum updated to 313
# pagenum updated to 314
# pagenum updated to 315
# pagenum updated to 316
# pagenum updated to 317
# pagenum updated to 318
# pagenum updated to 319
# pagenum updated to 320
# pagenum updated to 321
# pagenum updated to 322
# pagenum updated to 323
# pagenum updated to 324
# pagenum updated to 325
# pagenum updated to 326
# pagenum updated to 327
# pagenum updated to 328
# pagenum updated to 329
# pagenum updated to 330
# pagenum updated to 331
# pagenum updated to 332
# pagenum updated to 333
# pagenum updated to 334
# pagenum updated to 335
# pagenum updated to 336
# pagenum updated to 337
# pagenum updated to 338
# pagenum updated to 339
# pagenum updated to 340
# pagenum updated to 341
# pagenum updated to 342
# pagenum updated to 343
# pagenum updated to 344
# pagenum updated to 345
# pagenum updated to 346
# pagenum updated to 347
# pagenum updated to 348
# pagenum updated to 349
# pagenum updated to 350
# pagenum updated to 351
# pagenum updated to 352
# pagenum updated to 353
# pagenum updated to 354
# pagenum updated to 355
# pagenum updated to 356
# pagenum updated to 357
# pagenum updated to 358
# pagenum updated to 359
# pagenum updated to 360
# pagenum updated to 361
# pagenum updated to 362
# pagenum updated to 363
# pagenum updated to 364
# pagenum updated to 365
# pagenum updated to 366
# pagenum updated to 367
# pagenum updated to 368
# pagenum updated to 369
# pagenum updated to 370
# pagenum updated to 371
# pagenum updated to 372
# pagenum updated to 373
# pagenum updated to 374
# pagenum updated to 375
# pagenum updated to 376
# pagenum updated to 377
# pagenum updated to 378
# pagenum updated to 379
# pagenum updated to 380
# pagenum updated to 381
# pagenum updated to 382
# pagenum updated to 383
# pagenum updated to 384
# pagenum updated to 385
# pagenum updated to 386
# pagenum updated to 387
# pagenum updated to 388
# pagenum updated to 389
# pagenum updated to 390
# pagenum updated to 391
# pagenum updated to 392
# pagenum updated to 393
# pagenum updated to 394
# pagenum updated to 395
# pagenum updated to 396
# pagenum updated to 397
# pagenum updated to 398
# pagenum updated to 399
# pagenum updated to 400
# pagenum updated to 401
# pagenum updated to 402
# pagenum updated to 403
# pagenum updated to 404
# pagenum updated to 405
# pagenum updated to 406
# pagenum updated to 407
# pagenum updated to 408
# pagenum updated to 409
# pagenum updated to 410
# pagenum updated to 411
# pagenum updated to 412
# pagenum updated to 413
# pagenum updated to 414
# Batch Complete!
# pagenum updated to 2                                                                                 ] 0.32%
# pagenum updated to 3
# pagenum updated to 4
# pagenum updated to 5
# pagenum updated to 6
# pagenum updated to 7
# pagenum updated to 8
# pagenum updated to 9
# pagenum updated to 10
# pagenum updated to 11
# pagenum updated to 12
# pagenum updated to 13
# pagenum updated to 14
# pagenum updated to 15
# pagenum updated to 16
# pagenum updated to 17
# pagenum updated to 18
# pagenum updated to 19
# pagenum updated to 20
# pagenum updated to 21
# pagenum updated to 22
# pagenum updated to 23
# pagenum updated to 24
# pagenum updated to 25
# pagenum updated to 26
# pagenum updated to 27
# pagenum updated to 28
# pagenum updated to 29
# pagenum updated to 30
# pagenum updated to 31
# pagenum updated to 32
# pagenum updated to 33
# pagenum updated to 34
# pagenum updated to 35
# pagenum updated to 36
# pagenum updated to 37
# pagenum updated to 38
# pagenum updated to 39
# pagenum updated to 40
# pagenum updated to 41
# pagenum updated to 42
# pagenum updated to 43
# pagenum updated to 44
# pagenum updated to 45
# pagenum updated to 46
# pagenum updated to 47
# pagenum updated to 48
# pagenum updated to 49
# pagenum updated to 50
# pagenum updated to 51
# pagenum updated to 52
# pagenum updated to 53
# pagenum updated to 54
# pagenum updated to 55
# pagenum updated to 56
# pagenum updated to 57
# pagenum updated to 58
# pagenum updated to 59
# pagenum updated to 60
# pagenum updated to 61
# pagenum updated to 62
# pagenum updated to 63
# pagenum updated to 64
# pagenum updated to 65
# pagenum updated to 66
# pagenum updated to 67
# pagenum updated to 68
# pagenum updated to 69
# pagenum updated to 70
# pagenum updated to 71
# pagenum updated to 72
# pagenum updated to 73
# pagenum updated to 74
# pagenum updated to 75
# pagenum updated to 76
# pagenum updated to 77
# pagenum updated to 78
# pagenum updated to 79
# pagenum updated to 80
# pagenum updated to 81
# pagenum updated to 82
# pagenum updated to 83
# pagenum updated to 84
# pagenum updated to 85
# pagenum updated to 86
# pagenum updated to 87
# pagenum updated to 88
# pagenum updated to 89
# pagenum updated to 90
# pagenum updated to 91
# pagenum updated to 92
# pagenum updated to 93
# pagenum updated to 94
# pagenum updated to 95
# pagenum updated to 96
# pagenum updated to 97
# pagenum updated to 98
# pagenum updated to 99
# pagenum updated to 100
# pagenum updated to 101
# pagenum updated to 102
# pagenum updated to 103
# pagenum updated to 104
# pagenum updated to 105
# pagenum updated to 106
# pagenum updated to 107
# pagenum updated to 108
# pagenum updated to 109
# pagenum updated to 110
# pagenum updated to 111
# pagenum updated to 112
# pagenum updated to 113
# pagenum updated to 114
# pagenum updated to 115
# pagenum updated to 116
# pagenum updated to 117
# pagenum updated to 118
# pagenum updated to 119
# pagenum updated to 120
# pagenum updated to 121
# pagenum updated to 122
# pagenum updated to 123
# pagenum updated to 124
# pagenum updated to 125
# pagenum updated to 126
# pagenum updated to 127
# pagenum updated to 128
# pagenum updated to 129
# pagenum updated to 130
# pagenum updated to 131
# pagenum updated to 132
# pagenum updated to 133
# pagenum updated to 134
# pagenum updated to 135
# pagenum updated to 136
# pagenum updated to 137
# pagenum updated to 138
# pagenum updated to 139
# pagenum updated to 140
# pagenum updated to 141
# pagenum updated to 142
# pagenum updated to 143
# pagenum updated to 144
# pagenum updated to 145
# pagenum updated to 146
# pagenum updated to 147
# pagenum updated to 148
# pagenum updated to 149
# pagenum updated to 150
# pagenum updated to 151
# pagenum updated to 152
# pagenum updated to 153
# pagenum updated to 154
# pagenum updated to 155
# pagenum updated to 156
# pagenum updated to 157
# pagenum updated to 158
# pagenum updated to 159
# pagenum updated to 160
# pagenum updated to 161
# pagenum updated to 162
# pagenum updated to 163
# pagenum updated to 164
# pagenum updated to 165
# pagenum updated to 166
# pagenum updated to 167
# pagenum updated to 168
# pagenum updated to 169
# pagenum updated to 170
# pagenum updated to 171
# pagenum updated to 172
# pagenum updated to 173
# pagenum updated to 174
# pagenum updated to 175
# pagenum updated to 176
# pagenum updated to 177
# pagenum updated to 178
# pagenum updated to 179
# pagenum updated to 180
# pagenum updated to 181
# pagenum updated to 182
# pagenum updated to 183
# pagenum updated to 184
# pagenum updated to 185
# pagenum updated to 186
# pagenum updated to 187
# pagenum updated to 188
# pagenum updated to 189
# pagenum updated to 190
# pagenum updated to 191
# pagenum updated to 192
# pagenum updated to 193
# pagenum updated to 194
# pagenum updated to 195
# pagenum updated to 196
# pagenum updated to 197
# pagenum updated to 198
# pagenum updated to 199
# pagenum updated to 200
# pagenum updated to 201
# pagenum updated to 202
# pagenum updated to 203
# pagenum updated to 204
# pagenum updated to 205
# pagenum updated to 206
# pagenum updated to 207
# pagenum updated to 208
# pagenum updated to 209
# pagenum updated to 210
# pagenum updated to 211
# pagenum updated to 212
# pagenum updated to 213
# pagenum updated to 214
# pagenum updated to 215
# pagenum updated to 216
# pagenum updated to 217
# pagenum updated to 218
# pagenum updated to 219
# pagenum updated to 220
# pagenum updated to 221
# pagenum updated to 222
# pagenum updated to 223
# pagenum updated to 224
# pagenum updated to 225
# pagenum updated to 226
# pagenum updated to 227
# pagenum updated to 228
# pagenum updated to 229
# pagenum updated to 230
# pagenum updated to 231
# pagenum updated to 232
# pagenum updated to 233
# pagenum updated to 234
# pagenum updated to 235
# pagenum updated to 236
# pagenum updated to 237
# pagenum updated to 238
# pagenum updated to 239
# pagenum updated to 240
# pagenum updated to 241
# pagenum updated to 242
# pagenum updated to 243
# pagenum updated to 244
# pagenum updated to 245
# pagenum updated to 246
# pagenum updated to 247
# pagenum updated to 248
# pagenum updated to 249
# pagenum updated to 250
# pagenum updated to 251
# pagenum updated to 252
# pagenum updated to 253
# pagenum updated to 254
# pagenum updated to 255
# pagenum updated to 256
# pagenum updated to 257
# pagenum updated to 258
# pagenum updated to 259
# pagenum updated to 260
# pagenum updated to 261
# pagenum updated to 262
# pagenum updated to 263
# pagenum updated to 264
# pagenum updated to 265
# pagenum updated to 266
# pagenum updated to 267
# pagenum updated to 268
# pagenum updated to 269
# pagenum updated to 270
# pagenum updated to 271
# pagenum updated to 272
# pagenum updated to 273
# pagenum updated to 274
# pagenum updated to 275
# pagenum updated to 276
# pagenum updated to 277
# pagenum updated to 278
# pagenum updated to 279
# pagenum updated to 280
# pagenum updated to 281
# pagenum updated to 282
# pagenum updated to 283
# pagenum updated to 284
# pagenum updated to 285
# pagenum updated to 286
# pagenum updated to 287
# pagenum updated to 288
# pagenum updated to 289
# pagenum updated to 290
# pagenum updated to 291
# pagenum updated to 292
# pagenum updated to 293
# pagenum updated to 294
# pagenum updated to 295
# pagenum updated to 296
# Batch Complete!
# pagenum updated to 2                                                                                 ] 0.48%
# pagenum updated to 3
# pagenum updated to 4
# pagenum updated to 5
# pagenum updated to 6
# pagenum updated to 7
# pagenum updated to 8
# pagenum updated to 9
# pagenum updated to 10
# pagenum updated to 11
# pagenum updated to 12
# pagenum updated to 13
# pagenum updated to 14
# pagenum updated to 15
# pagenum updated to 16
# pagenum updated to 17
# pagenum updated to 18
# pagenum updated to 19
# pagenum updated to 20
# pagenum updated to 21
# pagenum updated to 22
# pagenum updated to 23
# pagenum updated to 24
# pagenum updated to 25
# pagenum updated to 26
# pagenum updated to 27
# pagenum updated to 28
# pagenum updated to 29
# pagenum updated to 30
# pagenum updated to 31
# pagenum updated to 32
# pagenum updated to 33
# pagenum updated to 34
# pagenum updated to 35
# pagenum updated to 36
# pagenum updated to 37
# pagenum updated to 38
# pagenum updated to 39
# pagenum updated to 40
# pagenum updated to 41
# pagenum updated to 42
# pagenum updated to 43
# pagenum updated to 44
# pagenum updated to 45
# pagenum updated to 46
# pagenum updated to 47
# pagenum updated to 48
# pagenum updated to 49
# pagenum updated to 50
# pagenum updated to 51
# pagenum updated to 52
# pagenum updated to 53
# pagenum updated to 54
# pagenum updated to 55
# pagenum updated to 56
# pagenum updated to 57
# pagenum updated to 58
# pagenum updated to 59
# pagenum updated to 60
# pagenum updated to 61
# pagenum updated to 62
# pagenum updated to 63
# pagenum updated to 64
# pagenum updated to 65
# pagenum updated to 66
# pagenum updated to 67
# pagenum updated to 68
# pagenum updated to 69
# pagenum updated to 70
# pagenum updated to 71
# pagenum updated to 72
# pagenum updated to 73
# pagenum updated to 74
# pagenum updated to 75
# pagenum updated to 76
# pagenum updated to 77
# pagenum updated to 78
# pagenum updated to 79
# pagenum updated to 80
# pagenum updated to 81
# pagenum updated to 82
# pagenum updated to 83
# pagenum updated to 84
# pagenum updated to 85
# pagenum updated to 86
# pagenum updated to 87
# pagenum updated to 88
# pagenum updated to 89
# pagenum updated to 90
# pagenum updated to 91
# pagenum updated to 92
# pagenum updated to 93
# pagenum updated to 94
# pagenum updated to 95
# pagenum updated to 96
# pagenum updated to 97
# pagenum updated to 98
# pagenum updated to 99
# pagenum updated to 100
# pagenum updated to 101
# pagenum updated to 102
# pagenum updated to 103
# pagenum updated to 104
# pagenum updated to 105
# pagenum updated to 106
# pagenum updated to 107
# pagenum updated to 108
# pagenum updated to 109
# pagenum updated to 110
# pagenum updated to 111
# pagenum updated to 112
# pagenum updated to 113
# pagenum updated to 114
# pagenum updated to 115
# pagenum updated to 116
# pagenum updated to 117
# pagenum updated to 118
# pagenum updated to 119
# pagenum updated to 120
# pagenum updated to 121
# pagenum updated to 122
# pagenum updated to 123
# pagenum updated to 124
# pagenum updated to 125
# pagenum updated to 126
# pagenum updated to 127
# pagenum updated to 128
# pagenum updated to 129
# pagenum updated to 130
# pagenum updated to 131
# pagenum updated to 132
# pagenum updated to 133
# pagenum updated to 134
# pagenum updated to 135
# pagenum updated to 136
# pagenum updated to 137
# pagenum updated to 138
# pagenum updated to 139
# pagenum updated to 140
# pagenum updated to 141
# pagenum updated to 142
# pagenum updated to 143
# pagenum updated to 144
# pagenum updated to 145
# pagenum updated to 146
# pagenum updated to 147
# pagenum updated to 148
# pagenum updated to 149
# pagenum updated to 150
# pagenum updated to 151
# pagenum updated to 152
# pagenum updated to 153
# pagenum updated to 154
# pagenum updated to 155
# pagenum updated to 156
# pagenum updated to 157
# pagenum updated to 158
# pagenum updated to 159
# pagenum updated to 160
# pagenum updated to 161
# pagenum updated to 162
# pagenum updated to 163
# pagenum updated to 164
# pagenum updated to 165
# pagenum updated to 166
# pagenum updated to 167
# pagenum updated to 168
# pagenum updated to 169
# pagenum updated to 170
# pagenum updated to 171
# pagenum updated to 172
# pagenum updated to 173
# pagenum updated to 174
# pagenum updated to 175
# pagenum updated to 176
# pagenum updated to 177
# pagenum updated to 178
# pagenum updated to 179
# pagenum updated to 180
# pagenum updated to 181
# pagenum updated to 182
# pagenum updated to 183
# pagenum updated to 184
# pagenum updated to 185
# pagenum updated to 186
# pagenum updated to 187
# pagenum updated to 188
# pagenum updated to 189
# pagenum updated to 190
# pagenum updated to 191
# pagenum updated to 192
# pagenum updated to 193
# pagenum updated to 194
# pagenum updated to 195
# pagenum updated to 196
# pagenum updated to 197
# pagenum updated to 198
# pagenum updated to 199
# pagenum updated to 200
# pagenum updated to 201
# pagenum updated to 202
# pagenum updated to 203
# pagenum updated to 204
# pagenum updated to 205
# pagenum updated to 206
# pagenum updated to 207
# pagenum updated to 208
# pagenum updated to 209
# pagenum updated to 210
# pagenum updated to 211
# pagenum updated to 212
# pagenum updated to 213
# pagenum updated to 214
# pagenum updated to 215
# pagenum updated to 216
# pagenum updated to 217
# pagenum updated to 218
# pagenum updated to 219
# pagenum updated to 220
# pagenum updated to 221
# pagenum updated to 222
# pagenum updated to 223
# pagenum updated to 224
# pagenum updated to 225
# pagenum updated to 226
# pagenum updated to 227
# pagenum updated to 228
# pagenum updated to 229
# pagenum updated to 230
# pagenum updated to 231
# pagenum updated to 232
# pagenum updated to 233
# pagenum updated to 234
# pagenum updated to 235
# pagenum updated to 236
# pagenum updated to 237
# pagenum updated to 238
# pagenum updated to 239
# pagenum updated to 240
# pagenum updated to 241
# pagenum updated to 242
# pagenum updated to 243
# pagenum updated to 244
# pagenum updated to 245
# pagenum updated to 246
# pagenum updated to 247
# Batch Complete!
# pagenum updated to 2                                                                                 ] 0.63%
# pagenum updated to 3
# pagenum updated to 4
# pagenum updated to 5
# pagenum updated to 6
# pagenum updated to 7
# pagenum updated to 8
# pagenum updated to 9
# pagenum updated to 10
# pagenum updated to 11
# pagenum updated to 12
# pagenum updated to 13
# pagenum updated to 14
# pagenum updated to 15
# pagenum updated to 16
# pagenum updated to 17
# pagenum updated to 18
# pagenum updated to 19
# pagenum updated to 20
# pagenum updated to 21
# pagenum updated to 22
# pagenum updated to 23
# pagenum updated to 24
# pagenum updated to 25
# pagenum updated to 26
# pagenum updated to 27
# pagenum updated to 28
# pagenum updated to 29
# pagenum updated to 30
# pagenum updated to 31
# pagenum updated to 32
# pagenum updated to 33
# pagenum updated to 34
# pagenum updated to 35
# pagenum updated to 36
# pagenum updated to 37
# pagenum updated to 38
# pagenum updated to 39
# pagenum updated to 40
# pagenum updated to 41
# pagenum updated to 42
# pagenum updated to 43
# pagenum updated to 44
# pagenum updated to 45
# pagenum updated to 46
# pagenum updated to 47
# pagenum updated to 48
# pagenum updated to 49
# pagenum updated to 50
# pagenum updated to 51
# pagenum updated to 52
# pagenum updated to 53
# pagenum updated to 54
# pagenum updated to 55
# pagenum updated to 56
# pagenum updated to 57
# pagenum updated to 58
# pagenum updated to 59
# pagenum updated to 60
# pagenum updated to 61
# pagenum updated to 62
# pagenum updated to 63
# pagenum updated to 64
# pagenum updated to 65
# pagenum updated to 66
# pagenum updated to 67
# pagenum updated to 68
# pagenum updated to 69
# pagenum updated to 70
# pagenum updated to 71
# pagenum updated to 72
# pagenum updated to 73
# pagenum updated to 74
# pagenum updated to 75
# pagenum updated to 76
# pagenum updated to 77
# pagenum updated to 78
# pagenum updated to 79
# pagenum updated to 80
# pagenum updated to 81
# pagenum updated to 82
# pagenum updated to 83
# pagenum updated to 84
# pagenum updated to 85
# pagenum updated to 86
# pagenum updated to 87
# pagenum updated to 88
# pagenum updated to 89
# pagenum updated to 90
# pagenum updated to 91
# pagenum updated to 92
# pagenum updated to 93
# pagenum updated to 94
# pagenum updated to 95
# pagenum updated to 96
# pagenum updated to 97
# pagenum updated to 98
# pagenum updated to 99
# pagenum updated to 100
# pagenum updated to 101
# pagenum updated to 102
# pagenum updated to 103
# pagenum updated to 104
# pagenum updated to 105
# pagenum updated to 106
# pagenum updated to 107
# pagenum updated to 108
# pagenum updated to 109
# pagenum updated to 110
# pagenum updated to 111
# pagenum updated to 112
# pagenum updated to 113
# pagenum updated to 114
# pagenum updated to 115
# pagenum updated to 116
# pagenum updated to 117
# pagenum updated to 118
# pagenum updated to 119
# pagenum updated to 120
# pagenum updated to 121
# pagenum updated to 122
# pagenum updated to 123
# pagenum updated to 124
# pagenum updated to 125
# pagenum updated to 126
# pagenum updated to 127
# pagenum updated to 128
# pagenum updated to 129
# pagenum updated to 130
# pagenum updated to 131
# pagenum updated to 132
# pagenum updated to 133
# pagenum updated to 134
# pagenum updated to 135
# pagenum updated to 136
# pagenum updated to 137
# pagenum updated to 138
# pagenum updated to 139
# pagenum updated to 140
# pagenum updated to 141
# pagenum updated to 142
# pagenum updated to 143
# pagenum updated to 144
# pagenum updated to 145
# pagenum updated to 146
# pagenum updated to 147
# pagenum updated to 148
# pagenum updated to 149
# pagenum updated to 150
# pagenum updated to 151
# pagenum updated to 152
# pagenum updated to 153
# pagenum updated to 154
# pagenum updated to 155
# pagenum updated to 156
# pagenum updated to 157
# pagenum updated to 158
# pagenum updated to 159
# pagenum updated to 160
# pagenum updated to 161
# pagenum updated to 162
# pagenum updated to 163
# pagenum updated to 164
# pagenum updated to 165
# pagenum updated to 166
# pagenum updated to 167
# pagenum updated to 168
# pagenum updated to 169
# pagenum updated to 170
# pagenum updated to 171
# pagenum updated to 172
# pagenum updated to 173
# pagenum updated to 174
# pagenum updated to 175
# pagenum updated to 176
# pagenum updated to 177
# pagenum updated to 178
# pagenum updated to 179
# pagenum updated to 180
# pagenum updated to 181
# pagenum updated to 182
# pagenum updated to 183
# pagenum updated to 184
# pagenum updated to 185
# pagenum updated to 186
# pagenum updated to 187
# pagenum updated to 188
# pagenum updated to 189
# pagenum updated to 190
# pagenum updated to 191
# pagenum updated to 192
# pagenum updated to 193
# pagenum updated to 194
# pagenum updated to 195
# pagenum updated to 196
# pagenum updated to 197
# pagenum updated to 198
# pagenum updated to 199
# pagenum updated to 200
# pagenum updated to 201
# pagenum updated to 202
# pagenum updated to 203
# pagenum updated to 204
# pagenum updated to 205
# pagenum updated to 206
# pagenum updated to 207
# pagenum updated to 208
# pagenum updated to 209
# pagenum updated to 210
# pagenum updated to 211
# pagenum updated to 212
# pagenum updated to 213
# pagenum updated to 214
# pagenum updated to 215
# Batch Complete!
# pagenum updated to 2                                                                                 ] 0.79%
# pagenum updated to 3
# pagenum updated to 4
# pagenum updated to 5
# pagenum updated to 6
# pagenum updated to 7
# pagenum updated to 8
# pagenum updated to 9
# pagenum updated to 10
# pagenum updated to 11
# pagenum updated to 12
# pagenum updated to 13
# pagenum updated to 14
# pagenum updated to 15
# pagenum updated to 16
# pagenum updated to 17
# pagenum updated to 18
# pagenum updated to 19
# pagenum updated to 20
# pagenum updated to 21
# pagenum updated to 22
# pagenum updated to 23
# pagenum updated to 24
# pagenum updated to 25
# pagenum updated to 26
# pagenum updated to 27
# pagenum updated to 28
# pagenum updated to 29
# pagenum updated to 30
# pagenum updated to 31
# pagenum updated to 32
# pagenum updated to 33
# ...
# Batch Complete!
# pagenum updated to 2*************************************************************                    ] 80.00%
# Batch Complete!
# pagenum updated to 2**************************************************************                   ] 80.16%
# Batch Complete!
# pagenum updated to 2**************************************************************                   ] 80.32%
# Batch Complete!
# pagenum updated to 2**************************************************************                   ] 80.48%
# Batch Complete!
# pagenum updated to 2**************************************************************                   ] 80.63%
# Batch Complete!
# pagenum updated to 2**************************************************************                   ] 80.79%
# Batch Complete!
# pagenum updated to 2**************************************************************                   ] 80.95%
# Batch Complete!
# pagenum updated to 2***************************************************************                  ] 81.11%
# Batch Complete!
# pagenum updated to 2***************************************************************                  ] 81.27%
# Batch Complete!
# pagenum updated to 2***************************************************************                  ] 81.43%
# Batch Complete!
# pagenum updated to 2***************************************************************                  ] 81.59%
# Batch Complete!
# pagenum updated to 2***************************************************************                  ] 81.75%
# Batch Complete!
# pagenum updated to 2***************************************************************                  ] 81.90%
# Batch Complete!
# pagenum updated to 2****************************************************************                 ] 82.06%
# Batch Complete!
# pagenum updated to 2****************************************************************                 ] 82.22%
# Batch Complete!
# pagenum updated to 2****************************************************************                 ] 82.38%
# Batch Complete!
# pagenum updated to 2****************************************************************                 ] 82.54%
# Batch Complete!
# pagenum updated to 2****************************************************************                 ] 82.70%
# Batch Complete!
# pagenum updated to 2****************************************************************                 ] 82.86%
# Batch Complete!
# pagenum updated to 2*****************************************************************                ] 83.02%
# Batch Complete!
# pagenum updated to 2*****************************************************************                ] 83.17%
# Batch Complete!
# pagenum updated to 2*****************************************************************                ] 83.33%
# Batch Complete!
# pagenum updated to 2*****************************************************************                ] 83.49%
# Batch Complete!
# pagenum updated to 2*****************************************************************                ] 83.65%
# Batch Complete!
# pagenum updated to 2*****************************************************************                ] 83.81%
# Batch Complete!
# pagenum updated to 2*****************************************************************                ] 83.97%
# Batch Complete!
# pagenum updated to 2******************************************************************               ] 84.13%
# Batch Complete!
# pagenum updated to 2******************************************************************               ] 84.29%
# Batch Complete!
# pagenum updated to 2******************************************************************               ] 84.44%
# Batch Complete!
# pagenum updated to 2******************************************************************               ] 84.60%
# Batch Complete!
# pagenum updated to 2******************************************************************               ] 84.76%
# Batch Complete!
# pagenum updated to 2******************************************************************               ] 84.92%
# Batch Complete!
# pagenum updated to 2*******************************************************************              ] 85.08%
# Batch Complete!
# pagenum updated to 2*******************************************************************              ] 85.24%
# Batch Complete!
# pagenum updated to 2*******************************************************************              ] 85.40%
# Batch Complete!
# pagenum updated to 2*******************************************************************              ] 85.56%
# Batch Complete!
# pagenum updated to 2*******************************************************************              ] 85.71%
# Batch Complete!
# pagenum updated to 2*******************************************************************              ] 85.87%
# Batch Complete!
# pagenum updated to 2********************************************************************             ] 86.03%
# Batch Complete!
# pagenum updated to 2********************************************************************             ] 86.19%
# Batch Complete!
# pagenum updated to 2********************************************************************             ] 86.35%
# Batch Complete!
# pagenum updated to 2********************************************************************             ] 86.51%
# Batch Complete!
# pagenum updated to 2********************************************************************             ] 86.67%
# Batch Complete!
# pagenum updated to 2********************************************************************             ] 86.83%
# Batch Complete!
# pagenum updated to 2********************************************************************             ] 86.98%
# Batch Complete!
# pagenum updated to 2*********************************************************************            ] 87.14%
# Batch Complete!
# pagenum updated to 2*********************************************************************            ] 87.30%
# Batch Complete!
# pagenum updated to 2*********************************************************************            ] 87.46%
# Batch Complete!
# pagenum updated to 2*********************************************************************            ] 87.62%
# Batch Complete!
# pagenum updated to 2*********************************************************************            ] 87.78%
# Batch Complete!
# pagenum updated to 2*********************************************************************            ] 87.94%
# Batch Complete!
# pagenum updated to 2**********************************************************************           ] 88.10%
# Batch Complete!
# pagenum updated to 2**********************************************************************           ] 88.25%
# Batch Complete!
# pagenum updated to 2**********************************************************************           ] 88.41%
# Batch Complete!
# pagenum updated to 2**********************************************************************           ] 88.57%
# Batch Complete!
# pagenum updated to 2**********************************************************************           ] 88.73%
# Batch Complete!
# pagenum updated to 2**********************************************************************           ] 88.89%
# Batch Complete!
# pagenum updated to 2***********************************************************************          ] 89.05%
# Batch Complete!
# pagenum updated to 2***********************************************************************          ] 89.21%
# Batch Complete!
# pagenum updated to 2***********************************************************************          ] 89.37%
# Batch Complete!
# pagenum updated to 2***********************************************************************          ] 89.52%
# Batch Complete!
# pagenum updated to 2***********************************************************************          ] 89.68%
# Batch Complete!
# pagenum updated to 2***********************************************************************          ] 89.84%
# Batch Complete!
# pagenum updated to 2***********************************************************************          ] 90.00%
# Batch Complete!
# pagenum updated to 2************************************************************************         ] 90.16%
# Batch Complete!
# pagenum updated to 2************************************************************************         ] 90.32%
# Batch Complete!
# pagenum updated to 2************************************************************************         ] 90.48%
# Batch Complete!
# pagenum updated to 2************************************************************************         ] 90.63%
# Batch Complete!
# pagenum updated to 2************************************************************************         ] 90.79%
# Batch Complete!
# pagenum updated to 2************************************************************************         ] 90.95%
# Batch Complete!
# pagenum updated to 2*************************************************************************        ] 91.11%
# Batch Complete!
# pagenum updated to 2*************************************************************************        ] 91.27%
# Batch Complete!
# pagenum updated to 2*************************************************************************        ] 91.43%
# Batch Complete!
# pagenum updated to 2*************************************************************************        ] 91.59%
# Batch Complete!
# pagenum updated to 2*************************************************************************        ] 91.75%
# Batch Complete!
# pagenum updated to 2*************************************************************************        ] 91.90%
# Batch Complete!
# pagenum updated to 2**************************************************************************       ] 92.06%
# Batch Complete!
# pagenum updated to 2**************************************************************************       ] 92.22%
# Batch Complete!
# pagenum updated to 2**************************************************************************       ] 92.38%
# Batch Complete!
# pagenum updated to 2**************************************************************************       ] 92.54%
# Batch Complete!
# pagenum updated to 2**************************************************************************       ] 92.70%
# Batch Complete!
# pagenum updated to 2**************************************************************************       ] 92.86%
# Batch Complete!
# pagenum updated to 2***************************************************************************      ] 93.02%
# Batch Complete!
# pagenum updated to 2***************************************************************************      ] 93.17%
# Batch Complete!
# pagenum updated to 2***************************************************************************      ] 93.33%
# Batch Complete!
# pagenum updated to 2***************************************************************************      ] 93.49%
# Batch Complete!
# pagenum updated to 2***************************************************************************      ] 93.65%
# Batch Complete!
# pagenum updated to 2***************************************************************************      ] 93.81%
# Batch Complete!
# pagenum updated to 2***************************************************************************      ] 93.97%
# Batch Complete!
# pagenum updated to 2****************************************************************************     ] 94.13%
# Batch Complete!
# pagenum updated to 2****************************************************************************     ] 94.29%
# Batch Complete!
# pagenum updated to 2****************************************************************************     ] 94.44%
# Batch Complete!
# pagenum updated to 2****************************************************************************     ] 94.60%
# Batch Complete!
# pagenum updated to 2****************************************************************************     ] 94.76%
# Batch Complete!
# pagenum updated to 2****************************************************************************     ] 94.92%
# Batch Complete!
# pagenum updated to 2*****************************************************************************    ] 95.08%
# Batch Complete!
# pagenum updated to 2*****************************************************************************    ] 95.24%
# Batch Complete!
# pagenum updated to 2*****************************************************************************    ] 95.40%
# Batch Complete!
# pagenum updated to 2*****************************************************************************    ] 95.56%
# Batch Complete!
# pagenum updated to 2*****************************************************************************    ] 95.71%
# Batch Complete!
# pagenum updated to 2*****************************************************************************    ] 95.87%
# Batch Complete!
# pagenum updated to 2******************************************************************************   ] 96.03%
# Batch Complete!
# pagenum updated to 2******************************************************************************   ] 96.19%
# Batch Complete!
# pagenum updated to 2******************************************************************************   ] 96.35%
# Batch Complete!
# pagenum updated to 2******************************************************************************   ] 96.51%
# Batch Complete!
# pagenum updated to 2******************************************************************************   ] 96.67%
# Batch Complete!
# pagenum updated to 2******************************************************************************   ] 96.83%
# Batch Complete!
# pagenum updated to 2******************************************************************************   ] 96.98%
# Batch Complete!
# pagenum updated to 2*******************************************************************************  ] 97.14%
# Batch Complete!
# pagenum updated to 2*******************************************************************************  ] 97.30%
# Batch Complete!
# pagenum updated to 2*******************************************************************************  ] 97.46%
# Batch Complete!
# pagenum updated to 2*******************************************************************************  ] 97.62%
# Batch Complete!
# pagenum updated to 2*******************************************************************************  ] 97.78%
# Batch Complete!
# pagenum updated to 2*******************************************************************************  ] 97.94%
# Batch Complete!
# pagenum updated to 2******************************************************************************** ] 98.10%
# Batch Complete!
# pagenum updated to 2******************************************************************************** ] 98.25%
# Batch Complete!
# pagenum updated to 2******************************************************************************** ] 98.41%
# Batch Complete!
# pagenum updated to 2******************************************************************************** ] 98.57%
# Batch Complete!
# pagenum updated to 2******************************************************************************** ] 98.73%
# Batch Complete!
# pagenum updated to 2******************************************************************************** ] 98.89%
# Batch Complete!
# pagenum updated to 2*********************************************************************************] 99.05%
# Batch Complete!
# Batch Complete!**************************************************************************************] 99.21%
# Batch Complete!**************************************************************************************] 99.37%
# Batch Complete!**************************************************************************************] 99.52%
# Batch Complete!**************************************************************************************] 99.68%
# Batch Complete!**************************************************************************************] 99.84%
# [****************************************************************************************************] 100.00%

# %% [markdown]
# Lastly, the final ratings from the partial pages are gathered and saved.

# %%
df['nfullpages']=(df['nrate']-50).apply(round, ndigits=-2)/100  

df_ratings=pd.DataFrame(columns=['username', 'gameid', 'rating'], index=range(5*10**5))

dfidx_start=0
dfidx=0

bar_counter=0
bar_total=len(df)
for idx, row in df.iterrows():
    pagenum=row['nfullpages']+1
    gameid=row['id']
    
    sleep(0.5)  
    r=request('http://www.boardgamegeek.com/xmlapi2/thing?id=%s&ratingcomments=1&page=%i' % (gameids, pagenum))
    
    soup=BeautifulSoup(r.text, 'xml')
    comments=soup('comment')

    id_list=[gameid]*len(comments)
    dfidx_end=dfidx_start+len(comments)
    df_ratings.iloc[dfidx_start:dfidx_end, df_ratings.columns.get_loc('gameid')] = id_list

    l1=[0]*len(comments)
    l2=[0]*len(comments)
    j=0
    for comm in comments:
        l1[j]=comm['username']
        l2[j]=float(comm['rating'])
        j+=1
    df_ratings.iloc[dfidx_start:dfidx_end, df_ratings.columns.get_loc('username')] = l1
    df_ratings.iloc[dfidx_start:dfidx_end, df_ratings.columns.get_loc('rating')] = l2

    dfidx_start=dfidx_end    

    if idx%100==0:
        
        df_ratings=df_ratings.dropna(how='all')
        df_ratings.to_csv('bgg_ratings.csv', mode='a',index=False)
        del df_ratings
        df_ratings=pd.DataFrame(columns=['username', 'gameid', 'rating'], index=range(5*10**5))
        
    bar_counter+=1
    show_progress_bar(100,bar_counter,bar_total)
    
df_ratings=df_ratings.dropna(how='all')

df_ratings.to_csv('bgg_ratings.csv', mode='a',index=False)
# Out:
# [****************************************************************************************************] 100.00%
